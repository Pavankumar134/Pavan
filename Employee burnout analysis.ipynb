# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
train = pd.read_csv("Train.csv")
test = pd.read_csv("Test.csv")

# %%
train
# Out:
#                   EmployeeID DateofJoining  Gender CompanyType WFHSetup  \
# 0   fffe32003000360033003200    30-09-2008  Female     Service       No
# 1       fffe3700360033003500    30-11-2008    Male     Service      Yes
# 2   fffe31003300320037003900    10-03-2008  Female     Product      Yes
# 3   fffe32003400380032003900    03-11-2008    Male     Service      Yes
# 4   fffe31003900340031003600    24-07-2008  Female     Service       No
# 5       fffe3300350037003500    26-11-2008    Male     Product      Yes
# 6   fffe33003300340039003100    02-01-2008  Female     Service       No
# 7   fffe32003600320037003400    31-10-2008  Female     Service      Yes
# 8   fffe32003200300034003700    27-12-2008  Female     Service       No
# 9   fffe31003600320030003200    09-03-2008  Female     Product       No
# 10  fffe33003100330032003700    16-03-2008    Male     Product      Yes
# 11      fffe3400310035003800    12-05-2008    Male     Service      Yes
# ...

# %%
test
# Out:
#                   EmployeeID DateofJoining  Gender CompanyType WFHSetup  \
# 0   fffe31003300390039003000    10-12-2008  Female     Service       No
# 1   fffe31003300310037003800    14-08-2008  Female     Product      Yes
# 2   fffe33003400380035003900    13-11-2008    Male     Product      Yes
# 3       fffe3100370039003200    07-02-2008  Female     Service       No
# 4   fffe32003600390036003700     7-07-2008  Female     Product       No
# 5       fffe3600390032003200    19-09-2008    Male     Product       No
# 6       fffe3600370032003200    16-01-2008  Female     Service      Yes
# 7   fffe32003900390030003000    10-02-2008    Male     Service       No
# 8       fffe3100370031003000     10-08-200    Male     Product      Yes
# 9   fffe31003500320037003600    20-05-2008    Male     Product      Yes
# 10      fffe3400370031003100    17-12-2008    Male     Service      Yes
# 11  fffe32003800300035003300    26-03-2008  Female     Service      Yes
# ...

# %%
train.head()
# Out:
#                  EmployeeID DateofJoining  Gender CompanyType WFHSetup  \
# 0  fffe32003000360033003200    30-09-2008  Female     Service       No
# 1      fffe3700360033003500    30-11-2008    Male     Service      Yes
# 2  fffe31003300320037003900    10-03-2008  Female     Product      Yes
# 3  fffe32003400380032003900    03-11-2008    Male     Service      Yes
# 4  fffe31003900340031003600    24-07-2008  Female     Service       No
#
#    Available  Designation  ResourceAllocation MentalFatigueScore  BurnRate
# 0        2.0          3.0                 3.8               0.16       NaN
# 1        1.0          2.0                 5.0               0.36       NaN
# 2        2.0          NaN                 5.8               0.49       NaN
# 3        1.0          1.0                 2.6                0.2       NaN
# 4        3.0          7.0                 6.9               0.52       NaN

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49 entries, 0 to 48
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   EmployeeID          49 non-null     object
#  1   DateofJoining       49 non-null     object
#  2   Gender              49 non-null     object
#  3   CompanyType         49 non-null     object
#  4   WFHSetup            49 non-null     object
#  5   Available           48 non-null     float64
#  6   Designation         46 non-null     float64
#  7   ResourceAllocation  39 non-null     float64
#  8   MentalFatigueScore  46 non-null     object
#  9   BurnRate            1 non-null      float64
# dtypes: float64(4), object(6)
# memory usage: 4.0+ KB

# %%
train.nunique()
# Out:
# EmployeeID            49
# DateofJoining         45
# Gender                 2
# CompanyType            2
# WFHSetup               3
# Available              5
# Designation           10
# ResourceAllocation    28
# MentalFatigueScore    34
# BurnRate               1
# dtype: int64

# %%
train.isnull().sum()
# Out:
# EmployeeID             0
# DateofJoining          0
# Gender                 0
# CompanyType            0
# WFHSetup               0
# Available              1
# Designation            3
# ResourceAllocation    10
# MentalFatigueScore     3
# BurnRate              48
# dtype: int64

# %%
test.isnull().sum()
# Out:
# EmployeeID             0
# DateofJoining          0
# Gender                 0
# CompanyType            0
# WFHSetup               0
# Availabl               0
# Designation            0
# ResourceAllocation     4
# MentalFatigueScore    49
# dtype: int64

# %%
train[['Gender', 'BurnRate']].groupby('Gender').agg('mean')
# Out:
#         BurnRate
# Gender
# Female      0.56
# Male         NaN

# %%
train.boxplot(column=['BurnRate'], by='Gender')
# Out:
# <Axes: title={'center': 'BurnRate'}, xlabel='Gender'>

# %%
train[['CompanyType', 'BurnRate']].groupby('CompanyType').agg('mean')
# Out:
#              BurnRate
# CompanyType
# Product           NaN
# Service          0.56

# %%
train.boxplot(column=['BurnRate'], by='CompanyType')
# Out:
# <Axes: title={'center': 'BurnRate'}, xlabel='CompanyType'>

# %%
train[['Designation', 'BurnRate']].groupby('Designation').agg('mean')
# Out:
#              BurnRate
# Designation
# 1.0               NaN
# 2.0               NaN
# 3.0               NaN
# 4.0               NaN
# 5.0               NaN
# 6.0              0.56
# 7.0               NaN
# 7.7               NaN
# 8.0               NaN
# 10.0              NaN

# %%
train.boxplot(column=['BurnRate'], by='Designation')
# Out:
# <Axes: title={'center': 'BurnRate'}, xlabel='Designation'>

# %%
train[['ResourceAllocation', 'BurnRate']].groupby('ResourceAllocation').agg('mean')
# Out:
#                     BurnRate
# ResourceAllocation
# 0.61                     NaN
# 1.80                     NaN
# 2.60                     NaN
# 3.00                     NaN
# 3.60                     NaN
# 3.80                     NaN
# 3.90                     NaN
# 4.00                     NaN
# 4.40                     NaN
# 4.70                     NaN
# 5.00                     NaN
# 5.30                     NaN
# 5.40                     NaN
# 5.80                     NaN
# 5.90                     NaN
# 6.00                     NaN
# 6.30                     NaN
# 6.60                     NaN
# 6.70                     NaN
# 6.90                     NaN
# 7.30                     NaN
# 7.40                     NaN
# 7.50                     NaN
# 7.60                     NaN
# 7.70                     NaN
# 7.90                     NaN
# 8.70                     NaN
# 10.00                    NaN

# %%
train.boxplot(column=['BurnRate'], by='ResourceAllocation')
# Out:
# <Axes: title={'center': 'BurnRate'}, xlabel='ResourceAllocation'>

# %%
train[['MentalFatigueScore', 'BurnRate']].groupby('MentalFatigueScore').agg('mean')
# Out:
#                     BurnRate
# MentalFatigueScore
#                          NaN
# 0.12                     NaN
# 0.16                     NaN
# 0.19                     NaN
# 0.2                      NaN
# 0.22                     NaN
# 0.29                     NaN
# 0.31                     NaN
# 0.32                     NaN
# 0.33                     NaN
# 0.36                     NaN
# 0.39                     NaN
# 0.4                      NaN
# 0.42                     NaN
# 0.44                     NaN
# 0.45                     NaN
# 0.46                     NaN
# 0.47                     NaN
# 0.49                     NaN
# 0.5                      NaN
# 0.51                     NaN
# 0.52                     NaN
# 0.53                     NaN
# 0.56                     NaN
# 0.57                     NaN
# 0.59                     NaN
# 0.6                      NaN
# 0.61                     NaN
# 0.62                     NaN
# 0.67                     NaN
# ...

# %%
train.boxplot(column=['BurnRate'], by='MentalFatigueScore')
# Out:
# <Axes: title={'center': 'BurnRate'}, xlabel='MentalFatigueScore'>

# %%
train.head()
# Out:
#                  EmployeeID DateofJoining  Gender CompanyType WFHSetup  \
# 0  fffe32003000360033003200    30-09-2008  Female     Service       No
# 1      fffe3700360033003500    30-11-2008    Male     Service      Yes
# 2  fffe31003300320037003900    10-03-2008  Female     Product      Yes
# 3  fffe32003400380032003900    03-11-2008    Male     Service      Yes
# 4  fffe31003900340031003600    24-07-2008  Female     Service       No
#
#    Available  Designation  ResourceAllocation MentalFatigueScore  BurnRate
# 0        2.0          3.0                 3.8               0.16       NaN
# 1        1.0          2.0                 5.0               0.36       NaN
# 2        2.0          NaN                 5.8               0.49       NaN
# 3        1.0          1.0                 2.6                0.2       NaN
# 4        3.0          7.0                 6.9               0.52       NaN

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49 entries, 0 to 48
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   EmployeeID          49 non-null     object
#  1   DateofJoining       49 non-null     object
#  2   Gender              49 non-null     object
#  3   CompanyType         49 non-null     object
#  4   WFHSetup            49 non-null     object
#  5   Available           48 non-null     float64
#  6   Designation         46 non-null     float64
#  7   ResourceAllocation  39 non-null     float64
#  8   MentalFatigueScore  46 non-null     object
#  9   BurnRate            1 non-null      float64
# dtypes: float64(4), object(6)
# memory usage: 4.0+ KB

# %%
train.nunique()
# Out:
# EmployeeID            49
# DateofJoining         45
# Gender                 2
# CompanyType            2
# WFHSetup               3
# Available              5
# Designation           10
# ResourceAllocation    28
# MentalFatigueScore    34
# BurnRate               1
# dtype: int64

# %%
train.isnull().sum()
# Out:
# EmployeeID             0
# DateofJoining          0
# Gender                 0
# CompanyType            0
# WFHSetup               0
# Available              1
# Designation            3
# ResourceAllocation    10
# MentalFatigueScore     3
# BurnRate              48
# dtype: int64

# %%
test.isnull().sum()
# Out:
# EmployeeID             0
# DateofJoining          0
# Gender                 0
# CompanyType            0
# WFHSetup               0
# Availabl               0
# Designation            0
# ResourceAllocation     4
# MentalFatigueScore    49
# dtype: int64

# %%
train[['Gender', 'BurnRate']].groupby('Gender').agg('mean')
# Out:
#         BurnRate
# Gender
# Female      0.56
# Male         NaN

# %%
train.boxplot(column=['BurnRate'], by='Gender')
# Out:
# <Axes: title={'center': 'BurnRate'}, xlabel='Gender'>

# %%
is_male = pd.get_dummies(train.Gender, drop_first=True)
is_service = pd.get_dummies(train["CompanyType"], drop_first=True)
wfh_available = pd.get_dummies(train["WFHSetup"], drop_first=True)

# %%
train.head()
# Out:
#                  EmployeeID DateofJoining  is_male  is_service  Gender  \
# 0  fffe32003000360033003200    30-09-2008        0           1  Female
# 1      fffe3700360033003500    30-11-2008        1           1    Male
# 2  fffe31003300320037003900    10-03-2008        0           0  Female
# 3  fffe32003400380032003900    03-11-2008        1           1    Male
# 4  fffe31003900340031003600    24-07-2008        0           1  Female
#
#   CompanyType WFHSetup  Available  Designation  ResourceAllocation  \
# 0     Service       No        2.0          3.0                 3.8
# 1     Service      Yes        1.0          2.0                 5.0
# 2     Product      Yes        2.0          NaN                 5.8
# 3     Service      Yes        1.0          1.0                 2.6
# 4     Service       No        3.0          7.0                 6.9
#
#   MentalFatigueScore  BurnRate
# 0               0.16       NaN
# 1               0.36       NaN
# 2               0.49       NaN
# ...

# %%
resource_nan = train["ResourceAllocation"].isna()
mental_nan = train["MentalFatigueScore"].isna()
burnrate_nan = train["BurnRate"].isna()

# No "Burn Rate" & "Mental Fatigue Score" values
train[(burnrate_nan) & (mental_nan)]
# Out:
#               EmployeeID DateofJoining  is_male  is_service  Gender  \
# 23  fffe3700370035003600    17-11-2008        0           0  Female
# 47  fffe3500320032003000    26-03-2008        0           0  Female
#
#    CompanyType WFHSetup  Available  Designation  ResourceAllocation  \
# 23     Product     Yes3        NaN          7.7                0.61
# 47     Product      Yes        3.0          6.0                 NaN
#
#    MentalFatigueScore  BurnRate
# 23                NaN       NaN
# 47                NaN       NaN

# %%
train_corr = train.corr()
# Out:
# C:\Users\pavan\AppData\Local\Temp\ipykernel_7188\1113871060.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   train_corr = train.corr()

# %%
plt.figure(figsize=(14, 6))
heatmap = sns.heatmap(train.corr(), vmin=-1, vmax=1, annot=True, center=0, cmap= 'coolwarm')
heatmap.set_title('Correlation Heatmap', fontdict={'fontsize':14}, pad=14);
plt.savefig("heatmap.png")
# Out:
# C:\Users\pavan\AppData\Local\Temp\ipykernel_7188\2340406571.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   heatmap = sns.heatmap(train.corr(), vmin=-1, vmax=1, annot=True, center=0, cmap= 'coolwarm')

# %%
describe_original = train.describe()
describe_original
# Out:
#          is_male  is_service  Available  Designation  ResourceAllocation  \
# count  49.000000   49.000000  48.000000    46.000000           39.000000
# mean    0.387755    0.693878   2.104167     4.406522            5.523333
# std     0.492287    0.465657   1.036352     2.071436            1.922381
# min     0.000000    0.000000   0.000000     1.000000            0.610000
# 25%     0.000000    0.000000   1.000000     3.000000            4.200000
# 50%     0.000000    1.000000   2.000000     4.000000            5.800000
# 75%     1.000000    1.000000   3.000000     6.000000            6.700000
# max     1.000000    1.000000   4.000000    10.000000           10.000000
#
#        BurnRate
# count      1.00
# mean       0.56
# std         NaN
# min        0.56
# 25%        0.56
# 50%        0.56
# 75%        0.56
# max        0.56

# %%
train.isna().sum()
# Out:
# EmployeeID             0
# DateofJoining          0
# is_male                0
# is_service             0
# Gender                 0
# CompanyType            0
# WFHSetup               0
# Available              1
# Designation            3
# ResourceAllocation    10
# MentalFatigueScore     3
# BurnRate              48
# dtype: int64

# %%
describe_botox = train.describe()

print("--------------- Original Data ---------------")
display(describe_original.iloc[:3, -3:])
print("\n--------------- Cleaned Data ---------------")
display(describe_botox.iloc[:3, -3:])
# Out:
# --------------- Original Data ---------------
#        Designation  ResourceAllocation  BurnRate
# count    46.000000           39.000000      1.00
# mean      4.406522            5.523333      0.56
# std       2.071436            1.922381       NaN
# --------------- Cleaned Data ---------------
#        Designation  ResourceAllocation  BurnRate
# count    46.000000           39.000000      1.00
# mean      4.406522            5.523333      0.56
# std       2.071436            1.922381       NaN

# %%
from sklearn.preprocessing import LabelEncoder
lr = LabelEncoder()

from sklearn.model_selection import train_test_split # Import train_test_split function
from sklearn import metrics

Id_train = train['EmployeeID']
X=train.drop(['BurnRate', 'EmployeeID', 'DateofJoining'],axis=1)
train['BurnRate']=LabelEncoder().fit_transform(train['BurnRate'])
y=train['BurnRate']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)

# %%
X_train.shape
# Out:
# (34, 9)

# %%
pip install keras
# Out:
# ...
#      ---------------------------------------- 1.7/1.7 MB 664.9 kB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install tensorflow
# Out:
# ...
#      -------------------------------------- 276.5/276.5 MB 1.5 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 24.4/24.4 MB 2.7 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 65.5/65.5 kB 1.8 MB/s eta 0:00:00
# ...
#      -------------------------------------- 126.5/126.5 kB 1.1 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 5.6/5.6 MB 2.3 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 4.2/4.2 MB 2.5 MB/s eta 0:00:00
# ...
#      -------------------------------------- 440.8/440.8 kB 1.7 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 57.5/57.5 kB 1.5 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 1.5/1.5 MB 166.9 kB/s eta 0:00:00
# ...
#      -------------------------------------- 422.5/422.5 kB 1.6 MB/s eta 0:00:00
# ...
#      -------------------------------------- 182.1/182.1 kB 1.8 MB/s eta 0:00:00
# ...
#      -------------------------------------- 151.7/151.7 kB 3.0 MB/s eta 0:00:00
# ...

# %%
from keras import models, layers
from keras.optimizers import Adam, schedules

# %%
def dense_layer(unit):
    model.add(layers.Dense(units=unit))
    model.add(layers.BatchNormalization())
    model.add(layers.Activation("relu"))

# %%
model = models.Sequential()
model.add(layers.Dense(units=16,
                       input_shape=(X_train.shape[1], ), 
                       kernel_initializer="GlorotUniform", 
                       name="Hidden_Layer1"))
model.add(layers.BatchNormalization())
model.add(layers.Activation("relu"))
#dense_layer(64)
model.add(layers.Dropout(0.05))
#dense_layer(128)
model.add(layers.Dense(1, name="Output_Layer"))
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  Hidden_Layer1 (Dense)       (None, 16)                160
#
#  batch_normalization (Batch  (None, 16)                64
#  Normalization)
#
#  activation (Activation)     (None, 16)                0
#
#  dropout (Dropout)           (None, 16)                0
#
#  Output_Layer (Dense)        (None, 1)                 17
#
# ...
# Total params: 241 (964.00 Byte)
# Trainable params: 209 (836.00 Byte)
# Non-trainable params: 32 (128.00 Byte)
# _________________________________________________________________
